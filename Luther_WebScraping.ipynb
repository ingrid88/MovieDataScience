# %% [markdown]
# # WebScraping

# %%
from dogpile.cache import make_region
import requests
from lxml import html
import csv
import pandas as pd
import pickle

# %%
from dogpile.cache import make_region

cache = make_region().configure(
    'dogpile.cache.memory',
    expiration_time = 24*2600
)

# %%
# Visualisation utils from Kris Joanidis
import IPython.display
def display_html(string, script = False, iframe = False, style  = False):
    '''Display HTML string in iPython notebook. <script> tags are removed by default.'''
    root = html.fromstring(string) 
    if not script:
        for element in root.iter("script"):
            element.drop_tree()
    if not iframe:
        for element in root.iter("iframe"):
            element.drop_tree()
    if not style:
        for element in root.iter("style"):
            element.drop_tree()
        for element in root.iter("link"):
            if element.attrib['rel'] == "stylesheet":
                element.drop_tree()
    IPython.display.display(IPython.display.HTML(html.tostring(root).decode('utf-8')))

# %% [markdown]
# ## WebScrape Box office mojo by year
# http://www.boxofficemojo.com/yearly/chart/?page="+str(pg)+"&view=releasedate&view1=domestic&yr="+str(yr)+"&p=.htm"

# %%
# @cache.cache_on_arguments()
def pull_page(yr):
    url = "http://www.boxofficemojo.com/oscar/chart/?yr="+str(yr)+"&view=allmovies&p=.htm"
    data = requests.get(url).text
    return data

def pull_mpage(yr,pg):
    url = "http://www.boxofficemojo.com/yearly/chart/?page="+str(pg)+"&view=releasedate&view1=domestic&yr="+str(yr)+"&p=.htm"
    data = requests.get(url).text
    return data
    
def make_soup(data):
    soup = BeautifulSoup(data,"lxml")
    return soup

# %%
## 2002 is the first year they add 'close' column to table. 

def mojo_movies():
    nmdf_list = []
    for yr in range(2002,2016):
        pg = 1
        page = html.fromstring(pull_mpage(yr,pg))
        tables = page.cssselect('table table table')
        while len(tables) > 0 :
            df = pd.read_html(html.tostring(tables[1]),header=0)[0]
            df.columns = ["Rank","Title","Studio", "Total_Gross","Gross_no_Theaters", "Opening",
                          "Opening_no_Theaters","Open_date","Close_date"]
            df = df.ix[df.index[1:-3]]

            df['Year'] = yr
            nmdf_list.append(df)

            pg += 1
            page = html.fromstring(pull_mpage(yr,pg))
            tables = page.cssselect('table table table')

    return nmdf_list

# %%
## PIPELINE
recent = mojo_movies()
df1 = pd.concat(recent)
df1.to_pickle('2002to2016movie_data.pkl')

# %% [markdown]
# ## WebScrape Box office mojo by oscars
# http://www.boxofficemojo.com/oscar/chart/?yr="+str(yr)+"&view=allmovies&p=.htm

# %%
def mojo_oscars():
    nmdf_list = []
    for yr in range(1980,2016):
        page = html.fromstring(pull_page(yr))
        tables = page.cssselect('table table')
        print tables
        df = pd.read_html(html.tostring(tables[1]),header=0)[0]
        df.columns = ["Row","YRRank","Picture","Studio","Box Office","Noms","Wins"]
        df['Year'] = yr
        nmdf_list.append(df)
    return nmdf_list

# %%
## PIPELINE
# recent = mojo_oscars()
# df1 = pd.concat(recent)
# df1.to_pickle('oscar2.pkl')

# %%
df1.head()
# Out:
#   Rank                                         Title Studio   Total_Gross  \
# 1    1                                    Spider-Man   Sony  $403,706,375
# 2    2         The Lord of the Rings: The Two Towers     NL  $339,789,881
# 3    3  Star Wars: Episode II - Attack of the Clones    Fox  $302,191,252
# 4    4       Harry Potter and the Chamber of Secrets     WB  $261,988,482
# 5    5                      My Big Fat Greek Wedding    IFC  $241,438,208
#
#   Gross_no_Theaters       Opening Opening_no_Theaters Open_date Close_date  \
# 1              3876  $114,844,116                3615       5/3       8/18
# 2              3622   $62,007,528                3622     12/18       8/24
# 3              3161   $80,027,814                3161      5/16       11/3
# 4              3682   $88,357,488                3682     11/15        5/4
# 5              2016      $597,362                 108      4/19       4/13
#
#    Year
# 1  2002
# 2  2002
# 3  2002
# 4  2002
# 5  2002

# %% [markdown]
# ## IMDB WebScrape
# 1. http://www.imdb.com/find?ref_=nv_sr_fn&q=  (search for movie title)
# 2. http://www.imdb.com/title/tt0076759/?ref_=fn_al_tt_1 (pull movie from search results)
# 3. capture ['IMDB_Score','Users','Metascore','Director','Writers','Actors','Genres','Rating','Title']

# %%
BASE_URL = 'http://www.imdb.com'

# %%
@cache.cache_on_arguments()


def imdb_data(title):
#     movie = '+'.join(title.split())
    title = '"%s"' % title
    movie = '+'.join(title.split())
    url = "%s/find?s=tt&q=%s" % (BASE_URL, movie)
    page = html.fromstring(requests.get(url).text)
    try: 
        movie_list = page.cssselect('table.findList tr td.result_text a')
#     display_html(html.tostring(page.cssselect('table.findList')[0]))
    except:
        movie_list = []
        failed_movies.append(title)
        print "failedHere"
    return movie_list

def imdb_page(movie_list):
#     if len(movie_list) >0:
    movie_link = movie_list[0].get('href')
    movie_page_url = BASE_URL + movie_link
    next_page = html.fromstring(requests.get(movie_page_url).text)
    print "next_page gotten"
    return next_page

def imdb_pull(next_page):
#     next_page = html.fromstring(requests.get(next_page).text)
    imdb_rating = next_page.cssselect('table div[class=star-box-details] span[itemprop=ratingValue]')[0].text_content()
#     print imdb_rating
    genres = next_page.cssselect('table div[class=infobar] span[itemprop="genre"]')
    genre_list = tuple([genre.text_content() for genre in genres])
#     rating = next_page.cssselect('table div[class=infobar] meta.content')[0]
#     print genre_list
    rating = next_page.cssselect('table div[class=infobar] meta')[0].get('content')
#     print rating
    users = next_page.cssselect('table div[class=star-box-details] span[itemprop=ratingCount]')[0].text_content()
#     print users
    metascore = next_page.cssselect('table div[class=star-box-details] a[href="criticreviews?ref_=tt_ov_rt"]')[0].text_content()
#     print metascore
    director = next_page.cssselect('table div[itemprop="director"] span[itemprop=name]')[0].text_content()
#     print director
    writers = next_page.cssselect('table div[itemprop="creator"] span[itemprop=name]')
    writer_list = tuple([writer.text_content() for writer in writers])
#     print writer_list
    actors = next_page.cssselect('table div[itemprop="actors"] span[itemprop=name]')
    actor_list = tuple([actor.text_content() for actor in actors])
#     print actor_list
    return [imdb_rating, users, metascore, director, writer_list, actor_list, genre_list,rating]

# %%
n_failed_movies = []

# %%
columns=["IMDB_Score","Users","Metascore","Director","Writers","Actors","Genres","Rating"]
imdb_df =pd.DataFrame(columns=columns) 

for title in ['Zoolander','Star Wars']:
    movie_list = imdb_data(title) 
    if len(movie_list) > 0:
        next_page = imdb_page(movie_list)
        try:
            row = imdb_pull(next_page)
            dictionary = dict(zip(columns,row))
            dictionary['Title'] = title
            imdb_df = imdb_df.append(dictionary, ignore_index=True)
        except:
            print "failed"
            n_failed_movies.append(title)
            continue
# Out:
# next_page gotten
# failed
# next_page gotten
# ['8.7', '855,336', ' 92/100\n', 'George Lucas', ('George Lucas',), ('Mark Hamill', 'Harrison Ford', 'Carrie Fisher'), ('Action', 'Adventure', 'Fantasy'), 'PG']

# %%
imdb_df.to_pickle('imdb_2')

# %%
# failed_movies
with open('imdb_failed_movies.pkl', 'w') as picklefile:
    pickle.dump(failed_movies, picklefile)

# %%
len(n_failed_movies)
# Out:
# 10

# %%
#unpickle
with open("titlelist.pkl", 'r') as picklefile: 
    movie_titles = pickle.load(picklefile)
with open("imdb_t6.pkl", 'r') as picklefile: 
    completed = pickle.load(picklefile)
with open("imdb_failed_movies.pkl", 'r') as picklefile: 
    failed_movies = pickle.load(picklefile)

# %%
m_titles = list(movie_titles.values)
c_titles = list(completed.Title.values)

# %%
ic_titles = set(m_titles) - (set(m_titles) & (set().union(*[c_titles,failed_movies])))
ic = sorted(ic_titles, reverse=True)

# %%
len(ic)
# Out:
# 410

# %%
ic = set(ic) - set([u"Le combat dans l'\xeele (1962)",u'A Prophet (Un proph\xe8te)'])
#  u"Le combat dans l'\xeele (1962)"

# %%
ic
# Out:
# {'101 Dalmatians (Re-issue) (1985)',
#  '101 Dalmatians (Re-issue) (1991)',
#  '1995 Bugs Bunny Film Festival',
#  '1998 Bugs Bunny Film Festival',
#  '2001: A Space Odyssey (2013 re-release)',
#  '2001: A Space Odyssey (Re-issue)',
#  '8 1/2 (re-issue)',
#  'A Christmas Story (Re-issue)',
#  "A Hard Day's Night (2014 re-release)",
#  "A Hard Day's Night (Re-issue)",
#  'A Man Vanishes (2012 re-release)',
#  'A Pig Across Paris (2013 re-issue)',
#  'A Poem Is a Naked Person (2015 re-issue)',
#  'A Trip to the Moon/The Extraordinary Voyage',
#  'Aarakshan (Reservation)',
#  "After Dark's Horror Fest: 8 Films to Die For",
#  "After Dark's Horrorfest 2",
#  'After the Life: Trilogy 3',
#  'Aftershock (Tangshan Dadizhen)',
#  'Aida at La Scala',
#  'Akira (Re-issue)',
#  'All About Eve (re-issue)',
#  'Alphaville (2013 re-release)',
#  "Amos Kolleck's Bad Girls",
#  'An Amazing Couple: Trilogy 2',
#  'Anchorman 2 (R-Rated Extended Cut)',
#  'Andrei Tarkovsky Retrospective',
#  'Antoine and Antoinette (2013 re-issue)',
#  'Asterix et Obelix: Mission Cleopatra',
#  'Au Hasard Balthazar (Re-issue)',
#  "Awesome: I F%!#in' Shot That",
#  "Bab'Aziz - The Prince Who Contemplated His Soul",
#  'Bad Blood (re-issue)',
#  'Bambi (Re-issue) (1982)',
#  'Bambi (Re-issue) (1988)',
#  'Band of Outsiders (Re-Issue)',
#  'Baraka (re-issue)',
#  "Barney's Version (U.S. only)",
#  'Batman Begins (2012 re-release)',
#  'Battleship Potemkin (2011 re-issue)',
#  'Bay of Angels (re-issue)',
#  'Beauty and the Beast (re-issue)',
#  'Becket (re-issue)',
#  'Belle De Jour (Re-issue)',
#  "Betty Blue: The Director's Cut",
#  'Blade Runner (re-issue)',
#  'Blazing Saddles (2013 re-release)',
#  'Blood Simple (re-issue)',
#  'Bon Voyage (Canada)',
#  'Bonjour M. Shlomi',
#  'BoyBand (2013)',
#  'Breathless (2010 re-issue)',
#  'Brighton Rock (re-issue)',
#  'Brothers: Blood Against Blood',
#  'Bully (PG-13)',
#  'Caravaggio (Re-issue)',
#  'Casablanca (2012 re-release)',
#  'Casablanca (2013 re-release)',
#  'Casablanca (Re-issue)',
#  'Celsius 41.11: The Truth Behind the Lies of Fahrenheit 9/11',
#  'Chaal Mera Bhai',
#  "Cheech and Chong's Corsican Bros.",
#  'Children of Paradise (2012 re-release)',
#  'Chocolat (1989)',
#  'Chocolat (2015 re-release)',
#  'Cinderella (Re-issue) (1981)',
#  'Cinderella (Re-issue) (1987)',
#  'Citizen Kane (Re-issue)',
#  'City Lights (re-issue)',
#  'Classe Tous Risques (re-issue)',
#  'Cobra Verde (re-issue)',
#  'Contempt (1997 re-issue)',
#  'Contempt (2013 re-release)',
#  'Contempt (re-issue)',
#  'Controlled Chaos (re-issue)',
#  'Cruising (re-issue)',
#  'Cyberworld 3-D (IMAX)',
#  'Daisies (2012 re-release)',
#  'Deep Sea 3D (IMAX)',
#  "Deitrick Haddon's A Beautiful Soul",
#  'Delirious (2007)',
#  'Detroit 9000 (Re-issue)',
#  "Dial 'M' for Murder (Re-issue)",
#  'Diary of a Country Priest (2011 re-release)',
#  'Dil Bole Hadippa! (My Heart Goes Hooray)',
#  'Diva (re-issue)',
#  'Django (2012 re-release)',
#  'Don Carlo at La Scala',
#  'Double Take (2010)',
#  'Dr. Cabbie (U.S. only)',
#  'Dr. Strangelove (Re-issue)',
#  'Edvard Munch (Re-issue)',
#  'El Topo (re-issue)',
#  'Elevator to the Gallows (Re-issue)',
#  'Elvis On Tour 75th Anniversary',
#  'Every Man for Himself (2010 re-issue)',
#  'Eye See You (a.k.a. D-TOX)',
#  'Eyes Without a Face (Re-issue)',
#  'Fanfan la Tulipe (1952) (re-issue)',
#  'Fantasia (Re-issue) (1985)',
#  'Fantasia (Re-issue) (1990)',
#  'Far Side of the Moon (Canada)',
#  'Fever Pitch (1999)',
#  'Fifty (IMAX)',
#  'Forza del Destino at Florence',
#  'Four Adventures of Reinette and Mirabelle (2011 re-release)',
#  'Friday the 13th Part III (Re-issue)',
#  "Fritz Lang's 'M' (2013 re-release)",
#  'From Here to Eternity (50th Anniversary)',
#  'From Mayerling to Sarajevo (2015 re-issue)',
#  'Funny Girl (re-issue)',
#  'Gabriela (1984)',
#  'Genghis Kahn: To the Ends of the Earth and Sea',
#  'GhettoPhysics: Will the Real Pimps and Hos Please Stand Up?',
#  'Ghostbusters (30th Anniversary re-release)',
#  'Giant (Re-issue)',
#  'Giorgio Moroder Presents Metropolis',
#  'Girlhood (2015)',
#  'Godzilla (Original Japanese Version)',
#  'Godzilla: The Japanese Original',
#  'Gone with the Wind (Re-issue) (1989)',
#  'Gone with the Wind (Re-issue) (1998)',
#  'Goonies (2013 re-release)',
#  'Grand Illusion (2012 re-release)',
#  'Grease (Re-issue)',
#  'Grease (Sing-a-Long re-issue)',
#  'Gremlins (Re-issue)',
#  'Grey Gardens (2015 re-release)',
#  'Guitar Innovators: John Fahey & Nels Cline',
#  'Hearts and Minds (Re-issue)',
#  'Heavy Metal (re-issue)',
#  "Henning Mankell's 'Wallander': The Revenge",
#  'Herbie Goes Bananas (Re-issue)',
#  'Hiroshima Mon Amour (2014 re-release)',
#  'Home (2009 French movie)',
#  'Home (2009 drama)',
#  'House (re-release)',
#  'How the West Was Won (re-issue)',
#  'If You Are the One 2 (Fei Cheng Wu Rao II)',
#  'Ikiru (Re-issue)',
#  'Il Trittico at La Scala',
#  'In & Out',
#  'Incendies (U.S. only)',
#  'InchAllah (U.S. only)',
#  'Inside the Mind of Leonardo Da Vinci in 3D',
#  'Jaws 2 (1980 re-issue)',
#  "Je T'aime, Je T'aime (2014 re-issue)",
#  'Jee Aayun Nu',
#  'Jet Lag (Canada)',
#  "Kahlil Gibran's The Prophet (Gathr)",
#  'Kevin Hart: Laugh at My Pain',
#  'Khi Pyar Na Ho Jaye',
#  'Killer of Sheep (re-issue)',
#  'Kyon? Ho Gaya Pyu',
#  "L'Age d'Or (Re-issue)",
#  'La Chinoise (re-issue)',
#  'La Rondine at Fenice',
#  'La Traviata at La Scala',
#  'Lady and the Tramp (Re-issue) (1980)',
#  'Lady and the Tramp (re-issue) (1986)',
#  'Lagaan (re-issue)',
#  'Larger than Life in 3D: Dave Matthews Band, Ben Harper and Gogol Bordello',
#  'Last Year at Marienbad (re-issue)',
#  'Lawrence of Arabia (re-issue) (1989)',
#  'Lawrence of Arabia (re-issue) (2002)',
#  'Le Amiche (re-issue)',
#  'Le Cercle Rouge (Re-issue)',
#  'Le Doulos (re-issue)',
#  'Le Jour Se Leve (2014 re-release)',
#  'Le Petit Soldat (2013 re-release)',
#  'Le Pont du Nord (2013 re-release)',
#  'Les Choristes (Quebec)',
#  'Life Is Beautiful (dubbed)',
#  'Little Fugitive (2013 re-release)',
#  'Lola (Demy) (re-issue)',
#  'Lola Montes (re-issue)',
#  'Made in U.S.A. (re-issue)',
#  'Mafioso (re-issue)',
#  'Magdalena, The Unholy Saint',
#  'Major Dundee (Re-issue)',
#  'Mala Noche (re-issue)',
#  'Mambo Italiano (Canada)',
#  'Manny amd Lo',
#  'Margaret Cho: The Assassin Tour',
#  'Maria Stuarda at La Scala',
#  'Marriage, Italian Style (2011 re-release)',
#  'Mary Poppins (re-issue)',
#  'Masculine Feminine (Re-issue)',
#  'Master Flying Guillotine (re-issue)',
#  'Mauvais Sang (2013 re-release)',
#  'Max et les Ferrailleurs (Max and the Junkmen) (2012 re-release)',
#  'Mean Streets (Re-issue)',
#  'Metropolis (2002 re-issue)',
#  'Metropolis (2010 re-issue)',
#  'Metropolis (re-issue)',
#  'Metropolitan (2015 re-release)',
#  'Mighty Peking Man (Re-issue)',
#  'Mississippi Mermaid (re-issue)',
#  'Modern Times (Re-issue)',
#  'Monsieur Lazhar (U.S.-only)',
#  'Monsieur Verdoux (re-issue)',
#  "Monty Python's Life of Brian (Re-issue)",
#  'Mughal-e-Azam (Re-issue)',
#  'Murmur of the Heart (Re-issue)',
#  "My Brother's Wedding (re-issue)",
#  'Neshoba: The Price of Freedom',
#  "Never Stand Still: Dancing at Jacob's Pillow",
#  'Nights of Cabiria (re-issue)',
#  'No',
#  'Northern Lights (2013 re-release)',
#  'Nothing But a Man (2012 re-release)',
#  'On the Bowery (re-release)',
#  'On the Run: Trilogy 1',
#  'One Bright Shining Moment: The Forgotten Summer of George McGovern',
#  'Orlando (re-issue)',
#  'Othello (2014 re-release)',
#  "Pandora's Box (1929) (re-issue)",
#  'Pariah (2000)',
#  'Peaceful Warrior (re-issue)',
#  'Pepe le Moko (re-issue)',
#  "Pete's Dragon (Re-issue)",
#  'Peter Pan (Re-issue) (1982)',
#  'Peter Pan (Re-issue) (1989)',
#  'Picnic at Hanging Rock (Re-issue)',
#  'Pierrot le fou (2015 re-issue)',
#  'Pinocchio (Italian version)',
#  'Pinocchio (Re-issue) (1984)',
#  'Pinocchio (Re-issue) (1992)',
#  "Porky's (Re-issue)",
#  "Porky's Revenge (Part III)",
#  'Port of Shadows (2012 re-issue)',
#  'Power and Terror (2006 playdate)',
#  'Promised Lands (2010 re-issue)',
#  'Pumpkinhead (Re-issue)',
#  'Quai des Orfevres (Re-issue)',
#  'Quebec sur ordonnace',
#  'Queen Margot (2014 re-release)',
#  'Raiders of the Lost Ark (Re-issue) (1982)',
#  'Raiders of the Lost Ark (Re-issue) (1983)',
#  'Ran (2010 re-issue)',
#  'Rear Window (Re-issue)',
#  'Rear Window (Re-issue) (1983)',
#  'Rififi (2015 re-release)',
#  'Rocky III (Re-issue)',
#  'Roving Mars (IMAX)',
#  'Russian Ark (2013 re-release)',
#  'Russian Ark (Canada)',
#  'Sahara (1984)',
#  'Sans Soleil (Re-issue)',
#  'Santa Vs. the Snowman - Season 2 (IMAX)',
#  'Santa Vs. the Snowman - Season 3 (IMAX)',
#  'Santa Vs. the Snowman - Season 4 (IMAX)',
#  'Santa Vs. the Snowman - Season 5 (IMAX)',
#  'Santa Vs. the Snowman - Season 6 (IMAX)',
#  'Santa Vs. the Snowman - Season 7 (IMAX)',
#  'Scarface (Re-issue)',
#  'Seven Samurai (re-issue)',
#  'Shoot the Piano Player (re-issue)',
#  'Short Eyes (Re-issue)',
#  "Singin' In the Rain (2012 re-release)",
#  "Singin' in the Rain (2013 re-release)",
#  'Six in Paris (re-issue)',
#  'Sleeping Beauty (2011) (II)',
#  'Small Change (re-issue)',
#  'Snow White and the Seven Dwarfs (Re-issue) (1983)',
#  'Snow White and the Seven Dwarfs (Re-issue) (1987)',
#  'Snow White and the Seven Dwarfs (Re-issue) (1993)',
#  'Sobibor, October 14, 1943, 4PM',
#  'Song of the South (Re-issue)',
#  'Song of the South (Re-issue) (1980)',
#  'Spartacus (re-issue)',
#  'Spider-Man / Men in Black II',
#  'Spooky House (Re-issue)',
#  'Starbuck (U.S. only)',
#  'Steal (a.k.a. Riders)',
#  "Steve Harvey's Don't Trip... He Ain't Through with Me Yet!",
#  'Stop Making Sense (re-issue)',
#  'Switchblade Sisters (Re-issue)',
#  'Tasuma: The Fighter',
#  'Taxi Driver (re-issue)',
#  'The Apu Trilogy',
#  'The Aristocats (Re-issue) (1980)',
#  'The Aristocats (Re-issue) (1987)',
#  'The Army of Shadows (2015 re-release)',
#  'The Battle of Algiers (re-issue)',
#  'The Beyond (re-issue)',
#  'The Bicycle Thief (1998 re-issue)',
#  'The Bicycle Thief (2009 re-issue)',
#  "The Big Blue (Director's Cut)",
#  'The Big Chill (re-issue)',
#  'The Boat Is Full (re-issue)',
#  'The Bodyguard (2012 re-release)',
#  'The Boys in the Band (re-issue)',
#  'The Bride Wore Black (2011 re-release)',
#  'The British Animation Invasion',
#  'The Cabinet of Dr. Caligari (2014 re-release)',
#  'The Conformist (2014 re-release)',
#  'The Cross: The Arthur Blessit Story',
#  'The Dark Knight (2012 re-release)',
#  'The Devil, Probably (2012 re-release)',
#  'The Empire Strikes Back (Re-issue)',
#  'The Empire Strikes Back (Special Edition)',
#  'The Endless Summer (2014 re-release)',
#  "The Endurance: Shackleton's Antarctic Adventure",
#  'The Exiles (re-issue)',
#  "The Exorcist Extended Director's Cut",
#  'The Fallen Idol (re-issue)',
#  'The Fassbinder Series',
#  'The Fellowship of the Ring - Extended Edition (Re-issue)',
#  'The Fox and the Hound (re-issue)',
#  'The Godfather (Re-issue)',
#  'The Good Old Naughty Days',
#  'The Graduate (re-issue)',
#  'The Graduate: 45th Anniversary Reunion',
#  'The Holy Mountain (re-issue)',
#  'The Intouchables (U.S.-only)',
#  'The Jungle Book (re-issue) (1984)',
#  'The Jungle Book (re-issue) (1990)',
#  'The Last Waltz (re-issue)',
#  'The Last Wave (Re-issue)',
#  'The Little Mermaid (Re-issue)',
#  'The Long Day Closes (2012 re-release)',
#  'The Lord of the Rings: The Fellowship of the Ring (2011 re-release)',
#  'The Lord of the Rings: The Return of the King (2011 re-release)',
#  'The Lord of the Rings: The Two Towers (2011 re-release)',
#  'The Man Who Fell to Earth (35th anniversary re-issue)',
#  'The Man in the White Suit (2012 re-release)',
#  'The Monster (Re-issue)',
#  'The Navigator (Re-issue)',
#  'The Optimists: The Story of the Rescue of the Bulgarian Jews from the Holocaust',
#  'The Ordeal (Calvaire)',
#  'The Other Conquest (re-issue)',
#  'The Other Man: F.W. de Klerk and the End of Apartheid in South Africa',
#  'The Passenger (re-issue)',
#  'The Passionate Thief (2014 re-release)',
#  'The Phantom of Liberte (Re-issue)',
#  'The Polar Express (2011 re-issue)',
#  'The Polar Express (2012 re-issue)',
#  'The Polar Express (IMAX re-issue 2005)',
#  'The Polar Express (IMAX re-issue 2006)',
#  'The Polar Express (IMAX re-issue 2007)',
#  'The Polar Express (IMAX re-issue 2008)',
#  'The Polar Express (IMAX re-issue 2009)',
#  'The Polar Express (IMAX re-issue 2010)',
#  'The Producers (re-issue)',
#  'The Pusher Trilogy',
#  'The Quay Brothers in 35mm',
#  'The Red Balloon / White Mane (re-issue)',
#  'The Rescuers (Re-issue)',
#  'The Rescuers (Re-issue) (1989)',
#  'The Rules of the Game (re-issue)',
#  'The Salvation Poem (Poema de Salvacion)',
#  'The Servant (2013 re-release)',
#  'The Shining (2013 re-release)',
#  'The Sword in the Stone (Re-issue)',
#  'The Tales of Hoffmann (2015 re-issue)',
#  'The Third Man (2015 re-release)',
#  'The Third Man (re-issue)',
#  'The Times of Harvey Milk (re-issue)',
#  'The Two Towers (Re-issue)',
#  'The Wicker Man - Final Cut',
#  'The Wild Bunch (re-issue)',
#  'The Wild Child (re-issue)',
#  'The Wizard of Oz (1989 re-issue)',
#  'The Wizard of Oz (1998 re-issue)',
#  'The Wizard of Oz (2002 re-issue)',
#  'The Wizard of Oz (3D/IMAX)',
#  'The Wizard of Oz (NCM Fathom Events)',
#  'The Woman with the Five Elephants',
#  'This is Spinal Tap (Re-issue)',
#  'Thrill Ride (IMAX)',
#  "Tim Burton's The Nightmare Before Christmas in 3-D (2008 re-issue)",
#  "Tim Burton's The Nightmare Before Christmas in 3-D (2009 re-issue)",
#  "Tim Burton's The Nightmare Before Christmas in Disney Digital 3-D (2007 re-issue)",
#  'Too Outrageous Animation',
#  "Tosca's Kiss (2014 re-release)",
#  'Total Recall (2012 re-release)',
#  'Touch of Evil (re-issue)',
#  'Touchez Pas Au Grisbi (Re-issue)',
#  'Tough Being Loved By Jerks',
#  'Tristan und Isolde at La Scala',
#  'Tristana (2012 re-release)',
#  'Trouble Every Day (2013 re-release)',
#  'Twilight/New Moon Combo (one-night-only)',
#  'Two by Scorsese (re-issue)',
#  'Two or Three Things I Know About Her (re-issue)',
#  'Tyler Perry Presents Peeples',
#  'Umberto D (re-issue)',
#  'Un Flic (2013 re-release)',
#  'Vertigo (1983 re-issue)',
#  'Vertigo (Restored 70mm) (re-issue)',
#  'Viva Pedro! (Almodovar festival)',
#  'Vivre sa vie (re-issue)',
#  'Wadjda (U.S. only)',
#  "Warren Miller's Journey (IMAX)",
#  'Wasabi Tuna (Re-issue)',
#  'Wattstax: The Special Edition',
#  "We Won't Grow Old Together (2012 re-release)",
#  'Went The Day Well? (2011 re-release)',
#  'What Women Want (Wo Zhi Nu Run Xin)',
#  'When a Stranger Calls (Re-issue)',
#  'Winged Migration (French Canadian)',
#  'Wolves (IMAX)',
#  'Women Who Flirt (Sajiao Nvren)',
#  'Wuthering Heights (Re-issue)',
#  'Z (40th anniv. re-issue)',
#  'Zatoichi (Canada)',
#  'Ziggy Stardust (Re-issue)'}

# %%
failed_movies
# Out:
# ['whaledreamers',
#  'Zyzzyx Road',
#  'Zus & Zo',
#  'Zoot Suit',
#  'Zoolander',
#  'Zoo',
#  'Zombie High',
#  'Zokkomon',
#  'Zindagi Rocks',
#  'Zindagi Na Milegi Dobara',
#  'Zinda',
#  'Zeus and Roxanne',
#  'Zero Patience',
#  'Zero Kelvin',
#  'Zero Effect',
#  'Zentropa',
#  'Zenith',
#  'Zelig',
#  'Zebrahead',
#  'Zapped!',
#  'Yuvvraaj',
#  'Yours, Mine and Ours',
#  'Your Mommy Kills Animals',
#  'Your Friends and Neighbors',
#  'Youngblood',
#  'Young and Wild',
#  'Young and Beautiful',
#  'Young Soul Rebels',
#  'Young Sherlock Holmes',
#  'Young Guns II',
#  'Young Girls of Rochefort (Re-issue)',
#  'Young Einstein',
#  'Young Doctors in Love',
#  'Young Detective Dee: Rise of the Sea Dragon',
#  "You're Gonna Miss Me",
#  "You'll Get Over It",
#  'You Will Be My Son',
#  'You So Crazy',
#  "You Ain't Seen Nothin' Yet",
#  'Yossi',
#  'Yor: Hunter from the Future',
#  'Yes, Giorgio',
#  'Yentl',
#  'Yellowbeard',
#  'Yellow Day (2015)',
#  'Yellow Day',
#  'Yellow Asphalt',
#  'Yella',
#  'Yeh Jawaani Hai Deewani',
#  'Year of the Gun',
#  'Year of the Dragon',
#  'Year of the Comet',
#  'Yangsi',
#  'Yamla Pagla Deewana',
#  'Yamakasi',
#  'Yaavarum Nalam',
#  'Yaadein',
#  'Xiu Xiu: The Sent Down Girl',
#  'X2: X-Men United',
#  'X-Men',
#  'X',
#  'Wuthering Heights (2012)',
#  'Wrongfully Accused',
#  'Wrong Is Right',
#  'Wrong (2013)',
#  'Wretches & Jabberers',
#  'Wrestling Ernest Hemingway',
#  'Worth Winning',
#  'World Gone Wild',
#  'Words of My Perfect Teacher',
#  'Wooly Boys',
#  'Woo',
#  'Wonderland (2003)',
#  'Wonderland (2000)',
#  'Wonderful Town',
#  'Woman on the Beach',
#  'Woman Is the Future of Man',
#  'Wolfen',
#  'Wolf',
#  'Without a Trace',
#  'Without a Clue',
#  "Without You I'm Nothing",
#  'Without Limits',
#  'Withnail and I',
#  'With Honors',
#  'Witchboard',
#  'Wishmaster',
#  'Wise Guys',
#  'Wisdom',
#  'Wired',
#  'Winter of Frozen Dreams',
#  'Winter People',
#  'Winter Flight',
#  'Wings of Honneamise',
#  'Wings of Courage (IMAX)',
#  'Windy City',
#  'Windsor Drive',
#  'Windrider',
#  'Windfall',
#  'Wind',
#  'Willow',
#  'Willie & Phil',
#  'Will You Still Love Me Tomorrow',
#  'Will It Snow for Christmas?',
#  'Wildfire: Feel the Heat (IMAX)',
#  'Wildfire',
#  'Wilder Napalm',
#  'Wildcats',
#  'Wild Tales',
#  'Wild Side',
#  'Wild Orchid 2',
#  'Wild Orchid',
#  'Wild Man Blues',
#  "Wild Hearts Can't Be Broken",
#  'Wild Grass',
#  'Wild Geese II',
#  'Wild City',
#  'Wild Bill',
#  'Wild America',
#  'Wigstock: The Movie',
#  "Widows' Peak",
#  'Wide Sargasso Sea',
#  'Wide Awake',
#  'Why Would I Lie?',
#  'Why Me?',
#  'Why Do Fools Fall in Love?',
#  'Whose Life Is It, Anyway?',
#  'Whore',
#  'Wholly Moses',
#  "Who's the Man?",
#  "Who's That Girl",
#  "Who's Harry Crumb?",
#  'Who the #$&% Is Jackson Pollock',
#  'Who Took Johnny',
#  'Who Shot Patakango?',
#  'Who Killed Bambi?',
#  'Who Is Harry Nilsson?',
#  'Who Does She Think She Is?',
#  'Whiz Kids',
#  'Whiteout',
#  'White Water Summer',
#  'White Sands',
#  'White Rainbow',
#  'White Palace',
#  'White Mischief',
#  "White Men Can't Jump",
#  "White Man's Burden",
#  'White Hunter, Black Heart',
#  'White God',
#  'White Fang II: Myth of the White Wolf',
#  'White Fang',
#  'White Elephant',
#  'White Dog',
#  'White',
#  'Whispers in the Dark',
#  'Where the Rivers Flow North',
#  'Where the River Runs Black',
#  'Where the Day Takes You',
#  'Where the Buffalo Roam',
#  'Where the Boys Are (1984)',
#  'Where Do We Go Now?',
#  'Where Angels Fear to Tread',
#  'Whensday',
#  'When the Wind Blows',
#  'When the Whales Came',
#  "When the Party's Over",
#  'When the Iron Bird Flies',
#  "When the Cat's Away",
#  'When a Man Loves a Woman',
#  'When Time Ran Out',
#  'When Night Is Falling',
#  'When Marnie Was There',
#  'When Father Was Away on Business',
#  'When Did You Last See Your Father',
#  'Whatever Happened to Harold Smith?',
#  "What's Your Rashee?",
#  "What's Love Got to Do with It",
#  "What's Eating Gilbert Grape",
#  'What the Snow Brings',
#  'What Time Is It There?',
#  'What Just Happened?',
#  'What Boys Like',
#  'Wetlands',
#  'Wetherby',
#  "Wes Craven's New Nightmare",
#  'Wes Craven Presents: They',
#  'Were the World Mine',
#  'Welcome to Woop Woop',
#  'Welcome Home, Roxy Carmichael',
#  'Welcome Home',
#  'Welcome Back',
#  'Weirdsville',
#  "Weekend at Bernie's II",
#  "Weekend at Bernie's",
#  'Weekend Warriors',
#  'Weekend Pass',
#  'Weekend (2011)',
#  'Weeds',
#  'Wedding Bell Blues',
#  "Weavers: Wasn't That a Time",
#  'Weapons of the Spirit',
#  "We're No Angels",
#  "We're Back! A Dinosaur's Story",
#  'We Think the World of You',
#  'We Have a Pope',
#  'We Go Way Back',
#  'We Are The Best!',
#  'We Are Family',
#  "Wayne's World 2",
#  'Waxwork',
#  'Waterland',
#  'Watercolors',
#  'Water Lilies',
#  'Water (Canada)',
#  'Washington Square',
#  'Washington Heights',
#  'Wash Dry and Spin Out',
#  'Wasabi Tuna',
#  'Warriors of the Rainbow: Seediq Bale',
#  'Warriors of Virtue',
#  'Warriors of Heaven and Earth',
#  'Warrior of Light',
#  'Warning Sign',
#  'Warlock: The Armageddon',
#  'Warlock',
#  'WarGames',
#  'War of the Buttons (2012)',
#  'War of the Buttons',
#  'War of the Arrows',
#  'War Party',
#  'War Eagle, Arkansas',
#  'Waqt - The Race Against Time',
#  'Wanted: Dead or Alive',
#  'Wanted (2009)',
#  'Waltzing Anna',
#  'Walt & El Grupo',
#  'Wallace and Gromit: The Curse of the Were-Rabbit',
#  'Wallace and Gromit',
#  'Walking on Dead Fish',
#  'Waking the Dead',
#  'Wake Up Sid',
#  'Waiting to Exhale',
#  'Waiting for the Moon',
#  'Waiting for the Light',
#  'Waiting for Happiness',
#  'Waiting for Dublin',
#  'Wagons East!',
#  'Wagner & Me',
#  'Waco: The Rules of Engagement',
#  'Wa-shoku: Beyond Sushi',
#  'WARx2',
#  'WALL-E',
#  'Voyager',
#  'Volunteers',
#  'Volere Volare',
#  'Vivere',
#  'Vito Bonafacci',
#  'Vital Signs',
#  'Visitors (2014)',
#  'Visiting Hours',
#  'Visions of Light',
#  'Vision Quest',
#  'Vision',
#  'Viruddh',
#  'Virtual Sexuality',
#  'Virginia',
#  'Virgin',
#  'Violets Are Blue',
#  'Violet Tendencies',
#  'Violet & Daisy',
#  'Vincent: The Life and Death of Vincent Van Gogh',
#  "Vince Vaughn's Wild West Comedy Show: 30 Days & 30 Nights - From Hollywood to the Heartland",
#  'Village of the Damned',
#  'Village Barbershop',
#  'Vigilante',
#  'Vicky Donor',
#  'Vice Versa',
#  'Vice Squad',
#  'Vibes',
#  'Vexille',
#  'Vettai',
#  'Veteran',
#  'Vertical Reality',
#  'Veronica Mars',
#  'Verdict on Auschwitz',
#  'Venus in Fur',
#  'Vengeance Is Mine (re-issue)',
#  'Veil of Tears',
#  'Veer!',
#  'Veer (2010)',
#  'Vanya on 42nd St.',
#  'Vanaja',
#  'Van Gogh',
#  "Valley of the Heart's Delight",
#  'Valley Girl',
#  'Vaastar',
#  'V.I. Warshawski',
#  'Uzumasa Limelight',
#  'Used People',
#  'Used Cars',
#  'Urban Cowboy',
#  'Up the Creek',
#  'Up Close and Personal',
#  'Up',
#  'Unzipped',
#  'Unveiled',
#  'Untold Scandal',
#  'Until the End of the World',
#  'Until September',
#  'Untamed Heart',
#  'Unraveled',
#  'Unnatural and Accidental',
#  'Unlawful Entry',
#  'Unknown Pleasures',
#  'Unknown (2006)',
#  'United Red Army',
#  'Uninvited Guest',
#  'Unidentified',
#  'Unhook the Stars',
#  'Unforgettable',
#  'Unfaithfully Yours (1984)',
#  'Undoing',
#  'Underworld',
#  'Undertow (2010)',
#  'Underground Comedy Movie',
#  'Underground',
#  'Undercover Blues',
#  'Under the Volcano',
#  'Under the Sun of Satan',
#  'Under the Skin of the City',
#  'Under the Rainbow',
#  'Under the Domim Tree',
#  'Under the Cherry Moon',
#  'Under the Boardwalk',
#  'Under Siege 2: Dark Territory',
#  'Under Siege',
#  'Under Fire',
#  'Undefeated (2012)',
#  'Uncut',
#  'Uncovered: The War on Iraq',
#  'Unconscious',
#  'Unconditional Love',
#  'Unconditional',
#  'Unborn in the USA',
#  'Un air de famille',
#  'Un Gallo con Muchos Huevos',
#  'Un Coeur en Hiver',
#  'Umrao Jaan',
#  'Ultrasuede',
#  'Ugly Me',
#  'Udaan',
#  'U2: Rattle and Hum',
#  'U Me Aur Hum',
#  'Typhoon',
#  "Tyler Perry's The Single Moms Club",
#  "Tyler Perry's Meet the Browns",
#  "Tyler Perry's Madea's Family Reunion",
#  "Tyler Perry's Madea's Big Happy Family",
#  "Tyler Perry's I Can Do Bad All By Myself",
#  "Tyler Perry's Good Deeds",
#  'Tying the Knot',
#  'Tycoon (2003)',
#  'Two-Bit Waltz',
#  'Two in the Wave',
#  'Two Much',
#  'Two Moon Junction',
#  'Two Lives',
#  'Two If by Sea',
#  'Two Girls in Love',
#  'Two Evil Eyes',
#  'Two Days, One Night',
#  'Two Bits',
#  'Twister (1990)',
#  'Twisted: A Balloonamentary',
#  'Twist of Faith',
#  'Twist (1993)',
#  'Twins',
#  'Twin Town',
#  'Twin Sisters',
#  'Twilight (1998)',
#  'Twice in a Lifetime',
#  'Twice Upon a Yesterday',
#  'Twentyfourseven',
#  'Twenty-One',
#  'Twenty Bucks',
#  'Twenty (2015)',
#  'Twelfth Night',
#  "Tuya's Marriage",
#  'Turtle Diary',
#  'Turtle Beach',
#  'Turk 182',
#  'Turbulence',
#  'Turbo: A Power Rangers Movie',
#  'Tune in Tomorrow',
#  'Tuff Turf',
#  'Tuesday, After Christmas',
#  'Tsahal',
#  'Trying to Get Good: The Jazz Odyssey of Jack Sheldon',
#  'Truth or Consequences, N.M.',
#  'Trust (2011)',
#  'Truly, Madly, Deeply',
#  'True Love',
#  'True Identity',
#  'True Friends',
#  'True Confessions',
#  'True Colors',
#  'True Believer',
#  'Tru Loved',
#  'Troublesome Creek: A Midwestern',
#  'Trouble in Mind',
#  'Troop Beverly Hills',
#  'Tron',
#  'Troll',
#  'Trojan War',
#  'Trojan Eddie',
#  'Triumph of the Wall',
#  'Triumph of the Spirit',
#  'Tristan and Isolde',
#  "Trippin'",
#  'Trigun: Badlands Rumble',
#  'Tricked',
#  'Trick or Treat',
#  'Trick',
#  'Tribute',
#  'Trial by Jury',
#  'Trial and Error',
#  'Trenchcoat',
#  'Trees Lounge',
#  'Treeless Mountain',
#  'Trapped in Paradise',
#  'Trapped',
#  'Transylvania 6-5000',
#  'Transformers: The Movie',
#  'Transformation: The Life and Legacy of Werner Erhard',
#  'Trail of the Pink Panther',
#  'Trading Mom',
#  'Tracks (2014)',
#  'Track 29',
#  'Traces of Red',
#  'Trace Amounts',
#  'Toys in the Attic',
#  'Toy Story / Toy Story 2 (3D)',
#  'Toy Soldiers',
#  'Tout est Parfait',
#  'Tous les Matins du Monde',
#  'Tour Truffaut',
#  'Tougher Than Leather',
#  "Tough Guys Don't Dance",
#  'Tough Guys',
#  'Tough Enough',
#  'Touch the Wall',
#  'Touch the Sound',
#  'Touch and Go',
#  'Touch',
#  'Toto Le Heros',
#  'Totally F---ed Up',
#  'Total Eclipse',
#  'Tosca',
#  'Torrents of Spring',
#  'Torn',
#  'Torch Song Trilogy',
#  'Top Secret!',
#  'Top Gun 3D',
#  'Top Gun',
#  'Top Dog',
#  'Too Beautiful For You',
#  'Tommy Boy',
#  'Tombstone',
#  'Tom and Viv',
#  'Tom and Huck',
#  'Tom & Jerry - The Movie',
#  'Tokyo Decadence',
#  'Together',
#  'Todo el Poder',
#  'To the Limit',
#  'To the Arctic (IMAX)',
#  'To Wong Foo, Thanks for Everything, Julie Newmar',
#  'To Sleep With Anger',
#  'To Live and Die in L.A.',
#  'To Live',
#  'To Gillian on Her 37th Birthday',
#  'To Die Like a Man',
#  'To Catch a Dollar',
#  'To Be or Not to Be (1983)',
#  'Tiny Times',
#  'Tin Men',
#  'Times and Winds',
#  'Time of Favor',
#  'Time Bandits',
#  'Time',
#  "Tim Burton's The Nightmare Before Christmas in 3-D (2006)",
#  "Tim Burton's The Nightmare Before Christmas (re-issue)",
#  "Tim Burton's The Nightmare Before Christmas",
#  "Tim Burton's Corpse Bride",
#  "Tim & Eric's Billion Dollar Movie",
#  'Till Human Voices Wake Us',
#  'Til There Was You',
#  'Tightrope',
#  'Tiger Warsaw',
#  'Thursday',
#  'Thunderstruck',
#  'Thunderheart',
#  'Thumbelina',
#  'Throw Momma From the Train',
#  'Through a Lens Darkly',
#  'Threesome',
#  'Three... Extremes',
#  'Three of Hearts',
#  'Three for the Road',
#  'Three Worlds',
#  'Three Wishes',
#  'Three Seasons',
#  "Three O' Clock High",
#  'Three Night Stand',
#  'Three Men and a Little Lady',
#  'Three Men and a Cradle',
#  'Three Men and a Baby',
#  'Three Fugitives',
#  'Three Amigos',
#  'Thousand Pieces of Gold',
#  'Those Lips, Those Eyes',
#  'Those Glory, Glory Days',
#  'Thomas in Love',
#  'Thoda Pyaar Thoda Magic',
#  'This is Not a Film',
#  'This World, Then the Fireworks',
#  "This Isn't Funny",
#  'This Is My Life',
#  'This Is My Father',
#  'This Is Elvis',
#  'This Binary Universe',
#  "This Ain't No Mouse Music!",
#  'Thirty Two Short Films About Glenn Gould',
#  'Thirteen Ghosts',
#  'Things Change',
#  'Things Are Tough All Over',
#  'Thieves (Les Voleurs)',
#  'Thief of Hearts',
#  'Thicker Than Water',
#  "They're Out of Business",
#  'They are We',
#  'They Come to America',
#  'They Call Me Bruce',
#  'Theremin: An Electronic Odyssey',
#  "There's No Place Like Utopia",
#  'There Goes My Baby',
#  'Thelonious Monk: Straight, No Chaser',
#  "The Young Poisoner's Handbook",
#  'The Young & Prodigious T.S. Spivet',
#  'The Year My Voice Broke',
#  'The X-Files',
#  'The Wrong Guys',
#  'The Wraith',
#  'The Worst Movie EVER!',
#  'The World of Kanako',
#  'The World Unseen',
#  'The World According to Shorts',
#  'The World According to Garp',
#  'The Work and the Story',
#  'The Work and the Glory III: A House Divided',
#  'The Work and the Glory II: American Zion',
#  'The Work and the Glory',
#  'The Wonderful, Horrible Life of Leni Riefenstahl',
#  'The Wonder of It All',
#  'The Women (2008)',
#  'The Woman in the Fifth',
#  'The Woman in Red',
#  'The Wolf at the Door',
#  'The Witnesses',
#  'The Witness (Wo shi zheng ren)',
#  'The Winter Guest',
#  'The Winners',
#  'The Winner',
#  'The Windmill Movie',
#  'The Wind Rises',
#  'The Wild Thornberrys',
#  'The Wild Life',
#  'The Wicker Man',
#  'The Wicked Lady',
#  "The Whore's Son",
#  'The Whole Wide World',
#  'The White Balloon',
#  'The Whales of August',
#  'The Whale',
#  "The Well-Digger's Daughter",
#  'The Weeping Meadow',
#  'The Weekend',
#  'The Wedding Banquet',
#  'The Weathered Underground',
#  'The Way We Laughed',
#  'The Way Home',
#  'The Way He Looks',
#  'The Way',
#  'The Waterdance',
#  'The Water Horse: Legend of the Deep',
#  'The Watcher in the Woods',
#  'The Wash',
#  'The Warrior and the Sorceress',
#  'The Warring States',
#  'The War at Home',
#  'The War Within',
#  'The Walking Dead',
#  'The Wackness',
#  'The Viral Factor',
#  'The Violin',
#  'The Vindicator',
#  'The Verdict',
#  'The Velocity of Gary',
#  'The Vanishing',
#  'The Vanished Empire',
#  'The Van',
#  'The Vagrant',
#  'The United States of Autism',
#  'The Unholy',
#  'The Understudy',
#  'The Undefeated (2011)',
#  'The Unborn (1991)',
#  'The Unbearable Lightness of Being',
#  'The Two of Us',
#  'The Two Escobars',
#  'The Tunnel (2011)',
#  'The Tunnel',
#  'The Trouble with Terkel',
#  'The Tripper',
#  'The Trip to Bountiful',
#  'The Trip (2011)',
#  'The Trip',
#  'The Trigger Effect',
#  'The Tribe',
#  'The Trials of Darryl Hunt',
#  'The Trial (2010)',
#  'The Trial',
#  'The Tree',
#  'The Toxic Avenger Part III: The Last Temptation of Toxie',
#  'The Toxic Avenger Part II',
#  'The Town Is Quiet',
#  'The Tower (2014)',
#  'The Time Guardian',
#  'The Tiger and the Snow',
#  'The Tie That Binds',
#  'The Three Musketeers (2011)',
#  'The Three Musketeers (1993)',
#  'The Thing Called Love',
#  'The Thing (2011)',
#  'The Thing (1982)',
#  'The Thief',
#  'The Texas Chainsaw Massacre 2',
#  'The Terrorist',
#  'The Terror Within',
#  'The Tenant (2011)',
#  'The Ten Commandments (2007)',
#  'The Ten',
#  'The Temptation of St. Tony',
#  'The Telephone',
#  'The Tango Lesson',
#  'The Tall Guy',
#  'The Taking of Beverly Hills',
#  'The Take',
#  'The Sword and the Sorcerer',
#  'The Swindle',
#  'The Swan Princess II',
#  'The Swan Princess',
#  'The Suspect (2014)',
#  'The Surfer King',
#  'The Sure Thing',
#  'The Super',
#  'The Sunchaser',
#  'The Summer House',
#  'The Sum of Us',
#  'The Substitute',
#  'The Stupids',
#  'The Stunt Man',
#  'The Strip',
#  'The Strange Case of Dr. Jekyll and Mr. Hyde',
#  'The Strange Case of Angelica',
#  'The Story of Qiu Ju',
#  'The Story of Boys and Girls',
#  'The Stone Boy',
#  'The Sting II',
#  'The Stars Fell on Henrietta',
#  'The Star Maker',
#  'The Star Chamber',
#  'The Square (2013)',
#  'The Square',
#  'The Spitfire Grill',
#  "The Spirit of '76",
#  'The Specials',
#  'The Specialist',
#  'The Song of Sparrows',
#  'The Song',
#  "The Son's Room",
#  'The Son',
#  'The Snow Walker',
#  'The Snapper',
#  'The Smurfs and the Magic Flute',
#  "The Slugger's Wife",
#  'The Slingshot',
#  'The Skin I Live In',
#  'The Singles Ward',
#  'The Singing Revolution',
#  'The Sicilian',
#  'The Show',
#  'The Shot',
#  'The Sheltering Sky',
#  'The Shadow',
#  'The Seventh Sign',
#  'The Settlers',
#  'The Serpent and the Rainbow',
#  'The Sensation of Sight',
#  'The Sender',
#  'The Seduction',
#  'The Secrets of Jonathan Sperry',
#  'The Secret of Roan Inish',
#  'The Secret of NIMH',
#  'The Secret of My Success',
#  'The Secret Rapture',
#  'The Secret Garden',
#  'The Secret Agent',
#  'The Secret Adventures of Tom Thumb',
#  'The Second Mother',
#  'The Second Jungle Book: Mowgli and Baloo',
#  'The Second Chance',
#  'The Search for Signs of Intelligent Life in the Universe',
#  'The Search for One-Eye Jimmy',
#  'The Scent of Green Papaya',
#  'The Scarlet Letter',
#  'The Saratov Approach',
#  'The Sandlot',
#  'The Salt of Life',
#  'The Saint of Fort Washington',
#  'The Sacrifice',
#  'The Russia House',
#  'The Running Man',
#  'The Rugrats Movie',
#  'The Rosary Murders',
#  'The Rookie (1990)',
#  'The Rook',
#  'The Rooftop',
#  'The Rocketeer',
#  'The Rocket (2014)',
#  'The Road to Wellville',
#  'The Road to Love',
#  'The Road Home',
#  'The Road (2012)',
#  'The River Within',
#  'The River Wild',
#  'The River Rat',
#  'The River',
#  'The Rise and Fall of Miss Thang',
#  'The Ringer',
#  'The Right Stuff',
#  "The Rich Man's Wife",
#  'The Revelation',
#  'The Return of the Swamp Thing',
#  'The Return of Superfly',
#  'The Return of Martin Guerre',
#  'The Return',
#  'The Rescuers Down Under',
#  'The Rescue',
#  'The Reflecting Skin',
#  'The Red Chapel',
#  'The Red Baron',
#  'The Real McCoy',
#  "The Razor's Edge",
#  'The Rapture',
#  'The Rainbow',
#  'The Rain Killer',
#  'The Rachel Papers',
#  "The Rabbi's Cat",
#  'The Quitter',
#  'The Quiet Earth',
#  'The Quest',
#  'The Pursuit of D.B. Cooper',
#  'The Puppet Masters',
#  'The Public Eye',
#  'The Protagonist',
#  "The Prophet's Son",
#  'The Prophecy',
#  'The Promise',
#  'The Principle',
#  'The Principal',
#  'The Princess and the Goblin',
#  'The Princess Academy',
#  'The Prince of the Himalayas',
#  'The Prince of Tides',
#  'The Prince of Pennsylvania',
#  'The Prince of Central Park',
#  'The Priests',
#  'The Presidio',
#  "The President's Last Bang",
#  "The Preacher's Wife",
#  'The Power of One',
#  'The Power of Few',
#  'The Power',
#  'The Postman Always Rings Twice',
#  'The Pope of Greenwich Village',
#  'The Pope Must Die(t)',
#  'The Pool',
#  'The Pleasure of Being Robbed',
#  'The Players Club',
#  'The Players',
#  'The Player',
#  'The Playboys',
#  'The Pirates! Band of Misfits',
#  'The Pirates of Penzance',
#  'The Pirates',
#  'The Pirate Movie',
#  'The Pickle',
#  'The Pick-Up Artist',
#  'The Photographer, His Wife, Her Lover',
#  'The Philadelphia Experiment II',
#  'The Philadelphia Experiment',
#  'The Phantom',
#  'The Pest',
#  'The Perils of Gwendolyn in the Land of Yik Yak',
#  'The Perfect Weapon',
#  'The Perez Family',
#  'The People Under the Stairs',
#  'The Pebble and the Penguin',
#  'The Patience Stone',
#  'The Past is a Grotesque Animal',
#  'The Pardon',
#  'The Panama Deception',
#  'The Pallbearer',
#  'The Painting (2013)',
#  'The Pagemaster',
#  'The Page Turner',
#  'The Package (2013)',
#  'The Package',
#  'The Oxford Murders',
#  'The Ox',
#  'The Overture',
#  'The Outskirts',
#  'The Outing',
#  'The Other World',
#  'The Other Side of the Street',
#  'The Other Side of Sunday',
#  'The Other One',
#  'The Other Conquest',
#  'The Osterman Weekend',
#  'The Opposite Sex and How to Live With Them',
#  'The Opera Lover',
#  'The Only Thrill',
#  'The One I Wrote For You',
#  'The One',
#  'The Omen (2006)',
#  'The Ogre',
#  'The Offspring',
#  'The Official Story',
#  'The Office',
#  'The Odd Couple II',
#  'The Octagon',
#  'The Object of Beauty',
#  'The Obama Effect',
#  'The Nutcracker Prince',
#  'The Nutcracker',
#  'The Number 23',
#  'The Nude Bomb',
#  'The Notebook (2014)',
#  'The Ninth Day',
#  'The Nines',
#  'The Night the Lights Went Out in Georgia',
#  'The Night of the Shooting Stars (Re-issue)',
#  'The Night of the Shooting Stars',
#  'The Night We Never Met',
#  'The Night Flier',
#  'The Next Karate Kid',
#  'The Next Big Thing',
#  'The New Twenty',
#  'The New Rijksmuseum',
#  'The New Kids',
#  'The New Girlfriend',
#  'The New Age',
#  'The Net',
#  'The Neon Bible',
#  'The Navigators',
#  'The Natural',
#  'The Nasty Girl',
#  'The Name of the Rose',
#  'The Naked Gun 33 1/3: The Final Insult',
#  'The Naked Gun 2 1/2: The Smell of Fear',
#  'The Mystery of Happiness',
#  'The Mutant Chronicles',
#  'The Musketeer',
#  'The Music of Chance',
#  'The Music Teacher',
#  'The Muse',
#  'The Muppets Take Manhattan',
#  'The Muppets',
#  'The Muppet Christmas Carol',
#  'The Mummy',
#  'The Mother',
#  'The Motel',
#  'The Morning After',
#  'The Monster Squad',
#  'The Monster',
#  'The Monk',
#  'The Money Pit',
#  'The Moderns',
#  'The Missionary',
#  'The Mission',
#  'The Missing Picture',
#  'The Missing Link',
#  'The Missing',
#  'The Mirror Has Two Faces',
#  "The Mirror Crack'd",
#  'The Mirror',
#  'The Miracle',
#  'The Ministers',
#  'The Milk of Sorrow',
#  'The Milagro Beanfield War',
#  'The Mighty Quinn',
#  'The Mighty Ducks',
#  'The Mighty',
#  'The Meteor Man',
#  'The Messengers',
#  'The Messenger',
#  'The Mesmerist',
#  "The Men's Club",
#  'The Mean Season',
#  'The Matchmaker',
#  'The Matador (2008)',
#  'The Marrying Man',
#  'The Manhattan Project',
#  'The Mangler',
#  'The Manchurian Candidate (re-issue)',
#  'The Man with One Red Shoe',
#  'The Man of My Life',
#  'The Man in the Moon',
#  'The Man in 3B',
#  'The Man Who Shook the Hand of Vicente Fernandez',
#  'The Man Who Loved Women',
#  'The Man Who Knew Too Little',
#  'The Man From Snowy River',
#  'The Man From Nowhere',
#  'The Mambo Kings',
#  'The Maid',
#  'The Magician (2010)',
#  'The Madness of King George',
#  'The Low Life',
#  'The Lovers on the Bridge',
#  'The Lover',
#  'The Love Letter',
#  'The Lottery',
#  'The Lost Medallion',
#  'The Lords of Discipline',
#  'The Lord of the Flies',
#  'The Looking Glass',
#  'The Long Weekend',
#  'The Long Way Home',
#  'The Long Walk Home',
#  'The Long Riders',
#  'The Lonely Lady',
#  'The Lonely Guy',
#  'The Locusts',
#  'The Living End',
#  'The Living Daylights',
#  'The Living',
#  'The Little Thief',
#  'The Little Rascals',
#  'The Little Mermaid',
#  'The Little Drummer Girl',
#  'The Lion King (in 3D)',
#  'The Lion King (IMAX)',
#  'The Line King: Al Hirschfeld',
#  'The Lighthorsemen',
#  'The Life and Times of Allen Ginsberg (Re-issue)',
#  'The Life and Times of Allen Ginsberg',
#  'The Lie',
#  'The Lesson',
#  'The Lesser Blessed',
#  'The Lemon Sisters',
#  'The Legend of the Lone Ranger',
#  'The Legend of Johnny Lingo',
#  "The Legend of God's Gun",
#  'The Legend of Billie Jean',
#  'The Leading Man',
#  'The Lawnmower Man',
#  'The Law in These Parts',
#  'The Law (re-release)',
#  'The Last of the High Kings',
#  'The Last of the Finest',
#  'The Last Women Standing',
#  'The Last Unicorn',
#  'The Last Time I Committed Suicide',
#  'The Last Supper',
#  'The Last Starfighter',
#  'The Last Shot',
#  'The Last Sentence',
#  'The Last Place on Earth',
#  'The Last Party',
#  'The Last Of The Unjust',
#  'The Last Mountain',
#  'The Last Metro',
#  'The Last Godfather',
#  "The Last Flight of Noah's Ark",
#  'The Last Fall',
#  'The Last Dragon',
#  'The Last Door',
#  'The Last Dispatch',
#  ...]

# %%
## http://data.bls.gov/pdq/SurveyOutputServlet 
cpi_excel = open('SeriesReport.xlsx','r')
cpidf = pd.read_excel(cpi_excel,header=9).set_index('Year')
cpi = cpidf.drop({'HALF1','HALF2'},axis=1)

# %%
completed.head()
# Out:
#   IMDB_Score      Users  Metascore            Director  \
# 0        7.3    516,078   73/100\n           Sam Raimi
# 1        8.7  1,037,342   88/100\n       Peter Jackson
# 2        6.7    437,662   54/100\n        George Lucas
# 3        7.4    366,162   63/100\n      Chris Columbus
# 4        6.7    262,736   59/100\n  M. Night Shyamalan
#
#                           Writers  \
# 0         (Stan Lee, Steve Ditko)
# 1    (J.R.R. Tolkien, Fran Walsh)
# 2  (George Lucas, Jonathan Hales)
# 3    (J.K. Rowling, Steve Kloves)
# 4           (M. Night Shyamalan,)
#
#                                               Actors  \
# 0       (Tobey Maguire, Kirsten Dunst, Willem Dafoe)
# 1       (Elijah Wood, Ian McKellen, Viggo Mortensen)
# 2  (Hayden Christensen, Natalie Portman, Ewan McG...
# 3      (Daniel Radcliffe, Rupert Grint, Emma Watson)
# 4         (Mel Gibson, Joaquin Phoenix, Rory Culkin)
#
#                          Genres Rating  \
# 0           (Action, Adventure)  PG-13
# 1   (Adventure, Drama, Fantasy)  PG-13
# 2  (Action, Adventure, Fantasy)     PG
# 3  (Adventure, Family, Fantasy)     PG
# 4     (Drama, Sci-Fi, Thriller)  PG-13
#
#                                           Title
# 0                                    Spider-Man
# 1         The Lord of the Rings: The Two Towers
# 2  Star Wars: Episode II - Attack of the Clones
# 3       Harry Potter and the Chamber of Secrets
# 4                                         Signs

# %%
## Base Period:  1982-84=100
# %matplotlib inline
from datetime import datetime
import matplotlib.pyplot as plt
cpi.head(n=10)
# cpi['Jan'][1980]
# plt.plot()
cpi.keys()pandas.to_datetime(*args,
# Out:
# Index([u'Jan', u'Feb', u'Mar', u'Apr', u'May', u'Jun', u'Jul', u'Aug', u'Sep',
#        u'Oct', u'Nov', u'Dec'],
#       dtype='object')

# %%
unstacked_cpi = cpi.unstack()

# %%
unstacked_cpi.reset_index()
# Out:
#     level_0  Year        0
# 0       Jan  1980   77.800
# 1       Jan  1981   87.000
# 2       Jan  1982   94.300
# 3       Jan  1983   97.800
# 4       Jan  1984  101.900
# 5       Jan  1985  105.500
# 6       Jan  1986  109.600
# 7       Jan  1987  111.200
# 8       Jan  1988  115.700
# 9       Jan  1989  121.100
# 10      Jan  1990  127.400
# 11      Jan  1991  134.600
# 12      Jan  1992  138.100
# 13      Jan  1993  142.600
# 14      Jan  1994  146.200
# 15      Jan  1995  150.300
# 16      Jan  1996  154.400
# 17      Jan  1997  159.100
# 18      Jan  1998  161.600
# 19      Jan  1999  164.300
# 20      Jan  2000  168.800
# 21      Jan  2001  175.100
# 22      Jan  2002  177.100
# 23      Jan  2003  181.700
# 24      Jan  2004  185.200
# 25      Jan  2005  190.700
# 26      Jan  2006  198.300
# 27      Jan  2007  202.416
# 28      Jan  2008  211.080
# 29      Jan  2009  211.143
# ..      ...   ...      ...
# 402     Dec  1986  110.500
# 403     Dec  1987  115.400
# 404     Dec  1988  120.500
# 405     Dec  1989  126.100
# 406     Dec  1990  133.800
# 407     Dec  1991  137.900
# 408     Dec  1992  141.900
# 409     Dec  1993  145.800
# 410     Dec  1994  149.700
# 411     Dec  1995  153.500
# 412     Dec  1996  158.600
# 413     Dec  1997  161.300
# 414     Dec  1998  163.900
# 415     Dec  1999  168.300
# 416     Dec  2000  174.000
# 417     Dec  2001  176.700
# 418     Dec  2002  180.900
# 419     Dec  2003  184.300
# 420     Dec  2004  190.300
# 421     Dec  2005  196.800
# 422     Dec  2006  201.800
# 423     Dec  2007  210.036
# 424     Dec  2008  210.228
# 425     Dec  2009  215.949
# 426     Dec  2010  219.179
# 427     Dec  2011  225.672
# 428     Dec  2012  229.601
# 429     Dec  2013  233.049
# 430     Dec  2014  234.812
# 431     Dec  2015  236.525
#
# [432 rows x 3 columns]

# %%
unstacked_cpi_df = pd.DataFrame(unstacked_cpi).reset_index()

# %%
unstacked_cpi_df.columns = ['month', 'year','cpi']

# %%
unstacked_cpi_df.head()
# Out:
#   month  year    cpi
# 0   Jan  1980   77.8
# 1   Jan  1981   87.0
# 2   Jan  1982   94.3
# 3   Jan  1983   97.8
# 4   Jan  1984  101.9

# %%
unstacked_cpi_df["Date"] = df.bar.map(str) + " is " + df.foo
# Out:
#     level_0  Year        0
# 0       Jan  1980   77.800
# 1       Jan  1981   87.000
# 2       Jan  1982   94.300
# 3       Jan  1983   97.800
# 4       Jan  1984  101.900
# 5       Jan  1985  105.500
# 6       Jan  1986  109.600
# 7       Jan  1987  111.200
# 8       Jan  1988  115.700
# 9       Jan  1989  121.100
# 10      Jan  1990  127.400
# 11      Jan  1991  134.600
# 12      Jan  1992  138.100
# 13      Jan  1993  142.600
# 14      Jan  1994  146.200
# 15      Jan  1995  150.300
# 16      Jan  1996  154.400
# 17      Jan  1997  159.100
# 18      Jan  1998  161.600
# 19      Jan  1999  164.300
# 20      Jan  2000  168.800
# 21      Jan  2001  175.100
# 22      Jan  2002  177.100
# 23      Jan  2003  181.700
# 24      Jan  2004  185.200
# 25      Jan  2005  190.700
# 26      Jan  2006  198.300
# 27      Jan  2007  202.416
# 28      Jan  2008  211.080
# 29      Jan  2009  211.143
# ..      ...   ...      ...
# 402     Dec  1986  110.500
# 403     Dec  1987  115.400
# 404     Dec  1988  120.500
# 405     Dec  1989  126.100
# 406     Dec  1990  133.800
# 407     Dec  1991  137.900
# 408     Dec  1992  141.900
# 409     Dec  1993  145.800
# 410     Dec  1994  149.700
# 411     Dec  1995  153.500
# 412     Dec  1996  158.600
# 413     Dec  1997  161.300
# 414     Dec  1998  163.900
# 415     Dec  1999  168.300
# 416     Dec  2000  174.000
# 417     Dec  2001  176.700
# 418     Dec  2002  180.900
# 419     Dec  2003  184.300
# 420     Dec  2004  190.300
# 421     Dec  2005  196.800
# 422     Dec  2006  201.800
# 423     Dec  2007  210.036
# 424     Dec  2008  210.228
# 425     Dec  2009  215.949
# 426     Dec  2010  219.179
# 427     Dec  2011  225.672
# 428     Dec  2012  229.601
# 429     Dec  2013  233.049
# 430     Dec  2014  234.812
# 431     Dec  2015  236.525
#
# [432 rows x 3 columns]
